# %% [markdown]
# <a href="https://colab.research.google.com/github/Devbrandlee/Python_CursoTec_IA/blob/main/Aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Primeiro notebook no Google Drive***

# %%
print("Olá mundo")
# Out:
# Olá mundo

# %% [markdown]
# Mini-desafio: Criar um notebook
# Escrever 3 prints com:
# > Nome
# > Curso
# > Uma frase motivacional
#
# Enviar o link do notebook

# %%
print("Nome: Brandon")

print("Curso: Téc. Em Inteligência Artificial")

print("Frase: O ser humano é aquilo que a educação faz dele.")
# Out:
# Nome:Brandon
# Curso:Téc. Em Inteligência Artificial
# Frase: O ser humano é aquilo que a educação faz dele.

# %% [markdown]
# **Exemplo com comando input que permite o usuário inserir informações no sistema**

# %%
nome = (input("Digite o seu nome:"))

curso = (input("Informe o nome do seu curso:"))

frase = (input("Insira uma frase que te motiva"))


#Exibe os valores digitados
print()
print(nome)
print()
print(curso)
print()
print( frase)

print()
print("Olá", nome, "Seja bem vindo(a) ao IFNMG!!")
# Out:
# Digite o seu nome:Brandon
# Informe o nome do seu curso:IA
# Insira uma frase que te motivaO ser humano é aquilo que a educação faz dele
#
# Brandon
#
# IA
#
# O ser humano é aquilo que a educação faz dele
#
# Olá Brandon Seja bem vindo(a) ao IFNMG!!

# %%
#Adição
a = 2
b = 3
soma = a + b

print("O valor de a + b é:" ,soma )
# Out:
# O valor de a + b é: 5
